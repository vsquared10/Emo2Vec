# %%
reset -fs

# %%
import collections
import math
import os
from pprint import pprint
import random
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf 
from sklearn.manifold import TSNE

# %matplotlib inline

# %%
filename = '../github/DSCI6004-student/corpora/Archive.zip'

# %%
# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

words = read_data(filename)
print('Dataset size: {:,} words'.format(len(words)))
# Out:
# Dataset size: 118,158 words

# %%
words[:5]
# Out:
# ['titl', 'a', 'winter', 'pilgrimag', 'author']

# %%
words[-5:]
# Out:
# ['it', 'wa', 'undertaken', 'and', 'accomplish']

# %%
len(reverse_dictionary)
# Out:
# 8500

# %%
vocabulary_size = 8500

def build_dataset(words):
    """ Replace rare words with UNK token which stands for "unknown".
    It is called a dustbin category, aka sweep the small count items into a single group.
    """
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Reduce memory by getting rid of the "heavy" list of strings

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, 
                               num_skips=2, 
                               skip_window=1)

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

# %%
# TensorFlow setup
graph = tf.Graph()

with graph.as_default():

    # Input data
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
      tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                     num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.initialize_all_variables()

# %%
num_steps = 100000 #100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to '%s':" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  217.532073975
# Nearest to 'that': corrod, manufactur, plung, grey, mansion, dispos, nightgar, moat,
# Nearest to 'time': herd, lest, miscellan, accordingli, handrail, remot, marbl, strove,
# Nearest to 'we': furious, peopl, ran, dusti, convent, anaesthet, governor, stork,
# Nearest to 'after': simpli, irksomeand, henc, ploughland, stunt, induc, banner, vigor,
# Nearest to 'and': orang, lloyd, sore, historian, xx, expert, blii, reproof,
# Nearest to 'mai': sylvia, calvaryth, prosper, saewulf, gratuit, savageri, embalm, clap,
# Nearest to 'or': power, vexati, came, pergamo, fortyon, souvent, familiar, min,
# Nearest to 'if': thatcapernaum, distancealthough, safe, fur, carven, access, lifetimeaft, romanc,
# Nearest to 'sai': museum, charm, symptom, pull, hospic, bush, perfunctori, similarli,
# Nearest to 'these': mutter, quaint, transcrib, bust, shutter, longfallen, zerk, stamp,
# Nearest to 'about': perchancehappi, neither, 1545, sat, boom, 600000, pole, blackskin,
# Nearest to 'but': distancealthough, shoreward, ago, whip, share, awkward, wealthier, jour,
# Nearest to 'all': poetri, vu, parentag, christian, rather, persever, baffo, titl,
# Nearest to 'upon': admiralti, believ, perpetu, 1600, amid, elderli, astound, coppermin,
# Nearest to 'now': whitehot, fireplac, situ, monkei, swaddlingcloth, slain, poor, shaven,
# Nearest to 'what': comfort, stare, xii, frighten, copiou, locomot, joppa, willow,
# Average loss at step  2000 :  37.6401505835
# Average loss at step  4000 :  7.05415631342
# Average loss at step  6000 :  5.04332436872
# Average loss at step  8000 :  4.6878606329
# Average loss at step  10000 :  4.55211566949
# Nearest to 'that': dispos, identif, manufactur, overflow, mansion, forum, decad, clergyman,
# Nearest to 'time': herd, lest, enemi, marbl, accordingli, remot, uniform, unchang,
# Nearest to 'we': i, thei, he, beguil, pictori, press, ran, close,
# Nearest to 'after': simpli, irksomeand, henc, vigor, banner, ploughland, induc, sheet,
# Nearest to 'and': jewel, unlock, uncertain, 330, sang, lode, purgatori, mummycas,
# Nearest to 'mai': sylvia, might, contrast, savageri, bitter, calvaryth, overwhelm, gaze,
# Nearest to 'or': souvent, suggest, announc, min, bottl, vexati, came, float,
# Nearest to 'if': thatcapernaum, distancealthough, reggio, pull, safe, quinin, lifetimeaft, hardli,
# Nearest to 'sai': charm, museum, hope, hospic, endeavour, bush, symptom, ptolemi,
# Nearest to 'these': the, mutter, quaint, stapledon, shutter, longfallen, hornsand, transcrib,
# Nearest to 'about': neither, benefit, perchancehappi, gethseman, boom, wine, sat, palestinewhat,
# Nearest to 'but': distancealthough, ephrath, ago, whip, share, butterfli, repeat, calm,
# Nearest to 'all': poetri, vu, titl, corner, christian, persever, troubl, sea,
# Nearest to 'upon': perpetu, bordon, amid, same, of, cat, eighti, handbag,
# Nearest to 'now': slain, swaddlingcloth, tend, cathol, regard, fireplac, situ, haifa,
# Nearest to 'what': frighten, stare, comfort, etc, honour, joppa, copiou, librari,
# Average loss at step  12000 :  4.45303342557
# Average loss at step  14000 :  4.38391596699
# Average loss at step  16000 :  4.32889930809
# Average loss at step  18000 :  4.27486902428
# Average loss at step  20000 :  4.22508809495
# Nearest to 'that': identif, dispos, manufactur, overflow, mansion, chapterroom, situat, forum,
# Nearest to 'time': herd, enemi, unchang, uniform, lest, accordingli, marbl, remot,
# Nearest to 'we': i, thei, beguil, caligula, pictori, he, vu, close,
# Nearest to 'after': simpli, irksomeand, vigor, henc, banner, regardless, ploughland, prevail,
# Nearest to 'and': unlock, sang, mummycas, jewel, lode, sore, obedi, afar,
# Nearest to 'mai': might, sylvia, contrast, calvaryth, savageri, overwhelm, talk, gaze,
# Nearest to 'or': min, souvent, bottl, announc, suggest, vexati, scrap, came,
# Nearest to 'if': thatcapernaum, distancealthough, quinin, reggio, as, rotunda, pull, naxo,
# Nearest to 'sai': charm, hope, museum, endeavour, symptom, hospic, bush, ptolemi,
# Nearest to 'these': the, mutter, quaint, hornsand, transcrib, remodel, longfallen, stapledon,
# Nearest to 'about': benefit, perchancehappi, 1545, palestinewhat, neither, theatr, gethseman, boom,
# Nearest to 'but': distancealthough, whip, ephrath, butterfli, ago, repeat, share, shoreward,
# Nearest to 'all': poetri, vu, titl, cash, troubl, persever, seeker, unlight,
# Nearest to 'upon': bordon, perpetu, sensibl, wednesdai, cat, handbag, amid, pointson,
# Nearest to 'now': slain, tend, swaddlingcloth, argiv, cathol, starv, fireplac, whitehot,
# Nearest to 'what': frighten, stare, honour, comfort, copiou, describedwh, joppa, xxi,
# Average loss at step  22000 :  4.17712346494
# Average loss at step  24000 :  4.13803107047
# Average loss at step  26000 :  4.09874013102
# Average loss at step  28000 :  4.06829861522
# Average loss at step  30000 :  4.04092563379
# Nearest to 'that': identif, dispos, manufactur, overflow, chapterroom, steampip, mansion, forum,
# Nearest to 'time': herd, enemi, unchang, uniform, notwithstand, lest, remot, marbl,
# Nearest to 'we': i, thei, beguil, caligula, vu, close, pictori, governor,
# Nearest to 'after': simpli, irksomeand, vigor, banner, regardless, henc, hilltop, hermet,
# Nearest to 'and': unlock, sang, jewel, mummycas, bitter, lode, sore, obedi,
# Nearest to 'mai': might, sylvia, overwhelm, contrast, calvaryth, savageri, talk, cannot,
# Nearest to 'or': min, souvent, bottl, scrap, announc, fastfad, vexati, conceit,
# Nearest to 'if': thatcapernaum, quinin, distancealthough, petti, rotunda, naxo, reggio, as,
# Nearest to 'sai': charm, hope, endeavour, museum, awok, symptom, bush, ptolemi,
# Nearest to 'these': remodel, transcrib, quaint, the, hornsand, mutter, longfallen, bust,
# Nearest to 'about': benefit, 1545, perchancehappi, palestinewhat, neither, profound, theatr, sow,
# Nearest to 'but': distancealthough, whip, ephrath, repeat, butterfli, ago, ambit, calm,
# Nearest to 'all': poetri, vu, titl, baffo, d, troubl, unlight, cash,
# Nearest to 'upon': bordon, sensibl, wednesdai, perpetu, arm, handbag, pointson, cat,
# Nearest to 'now': tend, slain, argiv, swaddlingcloth, overhang, whitehot, starv, fireplac,
# Nearest to 'what': frighten, stare, honour, describedwh, toil, comfort, joppa, copiou,
# Average loss at step  32000 :  4.01559059179
# Average loss at step  34000 :  3.99066815412
# Average loss at step  36000 :  3.96849613398
# Average loss at step  38000 :  3.94174118191
# Average loss at step  40000 :  3.91559823018
# Nearest to 'that': identif, dispos, manufactur, chapterroom, overflow, steampip, mansion, situat,
# Nearest to 'time': herd, unchang, enemi, uniform, notwithstand, remot, jehoshaphat, arena,
# Nearest to 'we': i, thei, beguil, caligula, vu, close, overcoat, dromund,
# Nearest to 'after': simpli, regardless, banner, vigor, irksomeand, hermet, hilltop, structur,
# Nearest to 'and': unlock, sang, mummycas, jewel, lode, sore, obedi, 330,
# Nearest to 'mai': might, cannot, overwhelm, calvaryth, sylvia, talk, savageri, emblem,
# Nearest to 'or': min, scrap, bottl, souvent, vexati, fortyon, bunch, announc,
# Nearest to 'if': quinin, thatcapernaum, petti, rotunda, naxo, distancealthough, courthous, unto,
# Nearest to 'sai': charm, hope, awok, endeavour, symptom, ptolemi, museum, bush,
# Nearest to 'these': remodel, transcrib, quaint, hornsand, longfallen, bust, mufti, mutter,
# Nearest to 'about': benefit, 1545, perchancehappi, palestinewhat, profound, neither, sow, theatr,
# Nearest to 'but': whip, distancealthough, ephrath, butterfli, repeat, ambit, ago, calm,
# Nearest to 'all': vu, titl, poetri, baffo, d, troubl, unlight, ventur,
# Nearest to 'upon': bordon, sensibl, arm, wednesdai, perpetu, pointson, gui, north,
# Nearest to 'now': tend, slain, argiv, overhang, swaddlingcloth, squander, whitehot, obscen,
# Nearest to 'what': frighten, honour, describedwh, wardrob, toil, stare, joppa, sparrow,
# Average loss at step  42000 :  3.89735276002
# Average loss at step  44000 :  3.88170305204
# Average loss at step  46000 :  3.86873682255
# Average loss at step  48000 :  3.85363917786
# Average loss at step  50000 :  3.83873985291
# Nearest to 'that': identif, dispos, manufactur, chapterroom, overflow, mansion, steampip, situat,
# Nearest to 'time': herd, enemi, unchang, uniform, pilgrimag, notwithstand, arena, remot,
# Nearest to 'we': i, thei, beguil, caligula, vu, close, dromund, whitetomb,
# Nearest to 'after': regardless, banner, simpli, facilit, vigor, hilltop, structur, hermet,
# Nearest to 'and': unlock, sang, mummycas, lode, sore, obedi, feather, jewel,
# Nearest to 'mai': cannot, might, overwhelm, talk, emblem, calvaryth, sylvia, savageri,
# Nearest to 'or': min, scrap, bottl, souvent, plunder, further, gentlemani, conceit,
# Nearest to 'if': quinin, thatcapernaum, petti, unto, rotunda, courthous, naxo, goodlookingpilgrim,
# Nearest to 'sai': charm, awok, hope, endeavour, symptom, ptolemi, recommend, museum,
# Nearest to 'these': remodel, transcrib, bust, longfallen, quaint, hornsand, mufti, green,
# Nearest to 'about': benefit, 1545, palestinewhat, perchancehappi, profound, sow, escort, plateau,
# Nearest to 'but': whip, distancealthough, butterfli, ephrath, repeat, ambit, behav, ago,
# Nearest to 'all': vu, titl, baffo, poetri, ventur, piteous, seeker, unlight,
# Nearest to 'upon': bordon, sensibl, arm, wednesdai, perpetu, north, undoubt, gui,
# Nearest to 'now': tend, slain, argiv, overhang, squander, soon, fireplac, swaddlingcloth,
# Nearest to 'what': frighten, describedwh, honour, wardrob, toil, sparrow, joppa, gain,
# Average loss at step  52000 :  3.81720007116
# Average loss at step  54000 :  3.80716367763
# Average loss at step  56000 :  3.78287739122
# Average loss at step  58000 :  3.77956759733
# Average loss at step  60000 :  3.76793220317
# Nearest to 'that': identif, dispos, chapterroom, overflow, steampip, manufactur, situat, concess,
# Nearest to 'time': herd, enemi, unchang, uniform, pilgrimag, arena, notwithstand, jehoshaphat,
# Nearest to 'we': i, thei, beguil, caligula, vu, close, dromund, overcoat,
# Nearest to 'after': regardless, banner, facilit, hilltop, grant, structur, 79, hermet,
# Nearest to 'and': unlock, sang, mummycas, sore, lode, bitter, slaughterhous, obedi,
# Nearest to 'mai': cannot, might, overwhelm, talk, emblem, savageri, rear, calvaryth,
# Nearest to 'or': min, scrap, bottl, fastfad, fix, plunder, souvent, further,
# Nearest to 'if': quinin, thatcapernaum, petti, unto, rotunda, dominican, courthous, goodlookingpilgrim,
# Nearest to 'sai': awok, charm, symptom, hope, endeavour, ptolemi, understand, recommend,
# Nearest to 'these': remodel, bust, transcrib, mufti, longfallen, 1322, green, quaint,
# Nearest to 'about': benefit, 1545, palestinewhat, perchancehappi, profound, famou, gain, escort,
# Nearest to 'but': distancealthough, butterfli, whip, repeat, ephrath, behav, ambit, fellowcountryman,
# Nearest to 'all': vu, titl, baffo, ventur, piteous, easier, poetri, seeker,
# Nearest to 'upon': bordon, sensibl, arm, wednesdai, north, perpetu, undoubt, befel,
# Nearest to 'now': tend, slain, argiv, squander, soon, obscen, overhang, prepar,
# Nearest to 'what': frighten, wardrob, honour, describedwh, toil, sparrow, joppa, gain,
# Average loss at step  62000 :  3.75501342708
# Average loss at step  64000 :  3.74408537275
# Average loss at step  66000 :  3.73141113371
# Average loss at step  68000 :  3.71484363967
# Average loss at step  70000 :  3.70326836157
# Nearest to 'that': identif, chapterroom, overflow, dispos, steampip, manufactur, situat, mansion,
# Nearest to 'time': herd, enemi, unchang, pilgrimag, uniform, arena, notwithstand, jehoshaphat,
# Nearest to 'we': i, thei, beguil, caligula, vu, dromund, overcoat, overs,
# Nearest to 'after': regardless, grant, hilltop, facilit, 79, structur, energynot, banner,
# Nearest to 'and': unlock, mummycas, sang, sore, jewel, lode, kloof, obedi,
# Nearest to 'mai': cannot, might, rear, emblem, talk, overwhelm, savageri, calvaryth,
# Nearest to 'or': min, scrap, bottl, unearth, plunder, fix, fling, gentlemani,
# Nearest to 'if': quinin, thatcapernaum, unto, dominican, petti, courthous, extraordinarili, goodlookingpilgrim,
# Nearest to 'sai': awok, charm, symptom, ptolemi, endeavour, hope, understand, recommend,
# Nearest to 'these': remodel, bust, mufti, transcrib, 1322, green, longfallen, satir,
# Nearest to 'about': benefit, 1545, profound, palestinewhat, perchancehappi, famou, gain, escort,
# Nearest to 'but': butterfli, distancealthough, whip, repeat, ephrath, behav, ambit, limouzin,
# Nearest to 'all': vu, titl, baffo, ventur, formal, luck, seeker, piteous,
# Nearest to 'upon': bordon, sensibl, arm, wednesdai, north, undoubt, holidai, perpetu,
# Nearest to 'now': tend, slain, argiv, soon, squander, obscen, swaddlingcloth, fireplac,
# Nearest to 'what': frighten, wardrob, describedwh, honour, toil, gain, joppa, sparrow,
# Average loss at step  72000 :  3.69393731171
# Average loss at step  74000 :  3.68851085711
# Average loss at step  76000 :  3.67705168658
# Average loss at step  78000 :  3.67024828368
# Average loss at step  80000 :  3.66437546137
# Nearest to 'that': identif, overflow, dispos, chapterroom, manufactur, situat, steampip, mansion,
# Nearest to 'time': enemi, herd, arena, pilgrimag, uniform, unchang, notwithstand, jehoshaphat,
# Nearest to 'we': thei, i, beguil, vu, caligula, overs, overcoat, dromund,
# Nearest to 'after': grant, 79, facilit, hilltop, regardless, eyewit, structur, energynot,
# Nearest to 'and': unlock, sang, mummycas, sore, obedi, undergo, kloof, expert,
# Nearest to 'mai': cannot, rear, might, talk, emblem, overwhelm, savageri, can,
# Nearest to 'or': min, scrap, plunder, bottl, gentlemani, fling, unearth, ba,
# Nearest to 'if': quinin, thatcapernaum, unto, courthous, dominican, goodlookingpilgrim, petti, activ,
# Nearest to 'sai': awok, charm, symptom, ptolemi, understand, recommend, vertigo, shipment,
# Nearest to 'these': remodel, bust, satir, 1322, mufti, green, transcrib, longfallen,
# Nearest to 'about': benefit, profound, palestinewhat, 1545, famou, gain, perchancehappi, plateau,
# Nearest to 'but': butterfli, distancealthough, whip, repeat, ephrath, behav, ambit, fellowcountryman,
# Nearest to 'all': baffo, titl, vu, formal, ventur, luck, seeker, piteous,
# Nearest to 'upon': bordon, arm, sensibl, undoubt, wednesdai, holidai, perpetu, north,
# Nearest to 'now': tend, slain, argiv, soon, receiv, obscen, squander, reckon,
# Nearest to 'what': frighten, wardrob, describedwh, honour, toil, joppa, righteous, gain,
# Average loss at step  82000 :  3.64572803366
# Average loss at step  84000 :  3.63987242651
# Average loss at step  86000 :  3.62206647956
# Average loss at step  88000 :  3.62880215231
# Average loss at step  90000 :  3.61262526256
# Nearest to 'that': identif, chapterroom, dispos, overflow, manufactur, steampip, situat, concess,
# Nearest to 'time': enemi, herd, arena, pilgrimag, unchang, uniform, notwithstand, graze,
# Nearest to 'we': thei, i, beguil, caligula, vu, overs, pelli, overcoat,
# Nearest to 'after': grant, 79, facilit, regardless, eyewit, hilltop, energynot, banner,
# Nearest to 'and': unlock, sang, lode, bitter, kloof, sore, obedi, caution,
# Nearest to 'mai': cannot, rear, emblem, might, talk, savageri, overwhelm, pad,
# Nearest to 'or': min, scrap, fling, bottl, unearth, gentlemani, souvenir, fix,
# Nearest to 'if': quinin, thatcapernaum, unto, goodlookingpilgrim, courthous, activ, dominican, petti,
# Nearest to 'sai': awok, charm, symptom, understand, vertigo, ptolemi, retreat, recommend,
# Nearest to 'these': remodel, bust, satir, mufti, 1322, green, transcrib, longfallen,
# Nearest to 'about': benefit, profound, palestinewhat, 1545, famou, gain, perchancehappi, plateau,
# Nearest to 'but': butterfli, distancealthough, whip, repeat, ephrath, behav, agreement, tragic,
# Nearest to 'all': baffo, formal, titl, luck, vu, ventur, seeker, breath,
# Nearest to 'upon': bordon, arm, sensibl, undoubt, wednesdai, holidai, north, faint,
# Nearest to 'now': tend, argiv, slain, receiv, reckon, soon, obscen, squander,
# Nearest to 'what': wardrob, describedwh, frighten, toil, honour, righteous, gain, joppa,
# Average loss at step  92000 :  3.60753689945
# Average loss at step  94000 :  3.60568993673
# Average loss at step  96000 :  3.59396268916
# Average loss at step  98000 :  3.58154035965

# %%
tsne = TSNE(perplexity=30, 
            n_components=2, 
            init='pca', 
            n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]

n_words_to_visualize = 40

for i, label in enumerate(labels[:n_words_to_visualize]):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)
